# %%
import pandas as pd
import json
from networkx import random_geometric_graph, set_node_attributes,betweenness_centrality
from pyvis.network import Network
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt

# %%
august_df = pd.read_csv('data/during_august_merged.csv')

# %%
august_df = august_df.drop(august_df[august_df['geoid_o'] == august_df['geoid_d']].index)

# %%
august_df = august_df.sort_values(by=['pop_flows'], ascending=False)

# %%
august_df['pop_flows_normalized'] = august_df['pop_flows'] / august_df['pop_o']

# %%
august_df.pop_flows = august_df.pop_flows.astype(int)

# %%
august_migration_df = august_df[['county_o', 'county_d', 'pop_flows', 'pop_flows_normalized']]

august_migration_json = august_migration_df.to_json(orient='records', indent=4)

with open('table.json', 'w') as f:
    f.write(august_migration_json)

# %%
class NpEncoder(json.JSONEncoder):
    def default(self, obj):
        if isinstance(obj, np.integer):
            return int(obj)
        if isinstance(obj, np.floating):
            return float(obj)
        if isinstance(obj, np.ndarray):
            return obj.tolist()
        return super(NpEncoder, self).default(obj)

# %%
august_migration_df.head(5)
# Out:
#                    county_o               county_d  pop_flows  \
# 963      Los Angeles County          Orange County     677050
# 969      Los Angeles County  San Bernardino County     369872
# 1794  San Bernardino County     Los Angeles County     335835
# 1808  San Bernardino County       Riverside County     256839
# 966      Los Angeles County       Riverside County     185927
#
#       pop_flows_normalized
# 963               0.067758
# 969               0.037016
# 1794              0.153825
# 1808              0.117642
# 966               0.018607

# %%
august_migration_df = august_migration_df.drop(august_migration_df[august_migration_df['pop_flows_normalized'] <= 0.003].index)

august_migration_df
# Out:
#                    county_o               county_d  pop_flows  \
# 963      Los Angeles County          Orange County     677050
# 969      Los Angeles County  San Bernardino County     369872
# 1794  San Bernardino County     Los Angeles County     335835
# 1808  San Bernardino County       Riverside County     256839
# 966      Los Angeles County       Riverside County     185927
# ...                     ...                    ...        ...
# 59            Alpine County          Amador County          4
# 86            Alpine County          Sierra County          4
# 69            Alpine County     Los Angeles County          4
# 62            Alpine County    Contra Costa County          4
# 88            Alpine County          Sonoma County          3
#
#       pop_flows_normalized
# 963               0.067758
# 969               0.037016
# 1794              0.153825
# 1808              0.117642
# 966               0.018607
# ...                    ...
# 59                0.003486
# 86                0.003380
# 69                0.003342
# 62                0.003322
# 88                0.003013
#
# [947 rows x 4 columns]

# %%
august_migration_df.pop_flows_normalized = august_migration_df.pop_flows_normalized * 100

# %%
august_migration_df
# Out:
#                    county_o               county_d  pop_flows  \
# 963      Los Angeles County          Orange County     677050
# 969      Los Angeles County  San Bernardino County     369872
# 1794  San Bernardino County     Los Angeles County     335835
# 1808  San Bernardino County       Riverside County     256839
# 966      Los Angeles County       Riverside County     185927
# ...                     ...                    ...        ...
# 59            Alpine County          Amador County          4
# 86            Alpine County          Sierra County          4
# 69            Alpine County     Los Angeles County          4
# 62            Alpine County    Contra Costa County          4
# 88            Alpine County          Sonoma County          3
#
#       pop_flows_normalized
# 963               6.775764
# 969               3.701603
# 1794             15.382454
# 1808             11.764164
# 966               1.860717
# ...                    ...
# 59                0.348644
# 86                0.338021
# 69                0.334157
# 62                0.332226
# 88                0.301321
#
# [947 rows x 4 columns]

# %%
nodes_df = pd.DataFrame({'binary': pd.unique(august_migration_df[['county_o', 'county_d']].values.ravel('K'))})

network_data = {
    "directed": True,
    "nodes": [],
    "links": [],
    "multigraph": False,
    "graph": []
}

# initiate nodes
for idx, node in nodes_df.iterrows():
    network_data['nodes'].append({
        "id": idx,
        "binary": node['binary'],
        "value": None
    })

# links
for idx, row in august_migration_df.iterrows():
    source_idx = nodes_df[nodes_df['binary'] == row['county_o']].index[0]
    target_idx = nodes_df[nodes_df['binary'] == row['county_d']].index[0]

    network_data['links'].append({
        "source": source_idx,
        "target": target_idx
    })

    # set values
    network_data['nodes'][source_idx]['value'] = float(row['pop_flows_normalized'])

nodes = network_data['nodes']

# dictionary to store the sampled nodes and links
sampled_network_data = {
    "directed": network_data["directed"],
    "nodes": nodes,
    "links": [],
    "multigraph": network_data["multigraph"],
    "graph": network_data["graph"]
}

node_id_mapping = {node["id"]: idx for idx, node in enumerate(nodes)}

# re-index
for node in sampled_network_data["nodes"]:
    old_id = node["id"]
    new_id = node_id_mapping[old_id]
    node["id"] = new_id

for link in network_data["links"]:
    source_id = link["source"]
    target_id = link["target"]

    if source_id in node_id_mapping and target_id in node_id_mapping:
        sampled_network_data["links"].append({
                "source": node_id_mapping[source_id],
                "target": node_id_mapping[target_id]
            })

# %%
counties = ['Mendocino County', 'Humboldt County', 'Trinity County', 'Tehama County', 'Glenn County', 'Lake County', 'Colusa County']

# Filter links based on source nodes in the specified counties
filtered_links = [link for link in sampled_network_data['links'] if sampled_network_data['nodes'][link['source']]['binary'] in counties]

# Update the network_data with the filtered links
sampled_network_data['links'] = filtered_links

target_ids = set(link['target'] for link in sampled_network_data['links'])
sampled_network_data['nodes'] = [node for node in sampled_network_data['nodes'] if node['id'] in target_ids]

# %%
# Create a mapping of old id values to new id values
id_mapping = {node["id"]: index for index, node in enumerate(sampled_network_data["nodes"])}

# Update the source and target values in links
for link in sampled_network_data["links"]:
    link["source"] = id_mapping.get(link["source"])
    link["target"] = id_mapping.get(link["target"])

# %%
sampled_network_data
# Out:
# {'directed': True,
#  'nodes': [{'id': 0,
#    'binary': 'Los Angeles County',
#    'value': 0.3980144835613161},
#   {'id': 1, 'binary': 'San Bernardino County', 'value': 0.5091677474252384},
#   {'id': 2, 'binary': 'Contra Costa County', 'value': 0.30652767421237137},
#   {'id': 4, 'binary': 'Sacramento County', 'value': 0.31858602704462363},
#   {'id': 5, 'binary': 'Alameda County', 'value': 0.34314220731357276},
#   {'id': 6, 'binary': 'Santa Clara County', 'value': 0.30154532381496485},
#   {'id': 7, 'binary': 'Placer County', 'value': 0.3165718293814662},
#   {'id': 8, 'binary': 'San Mateo County', 'value': 0.34571670532972565},
#   {'id': 9, 'binary': 'Kern County', 'value': 0.3198089046321336},
#   {'id': 11, 'binary': 'San Joaquin County', 'value': 0.32579853279678217},
#   {'id': 13, 'binary': 'El Dorado County', 'value': 0.3298465422756693},
#   {'id': 14, 'binary': 'Yolo County', 'value': 0.30361228461268747},
#   {'id': 15, 'binary': 'Merced County', 'value': 0.3191243903079072},
#   {'id': 18, 'binary': 'Solano County', 'value': 0.42118021696686336},
#   {'id': 19, 'binary': 'Fresno County', 'value': 0.32422125103283034},
#   {'id': 22, 'binary': 'Yuba County', 'value': 0.3163731208919995},
#   {'id': 23, 'binary': 'Sonoma County', 'value': 0.37455557781896753},
#   {'id': 27, 'binary': 'Napa County', 'value': 0.3005063554501929},
#   {'id': 29, 'binary': 'Tehama County', 'value': 0.3128179962228156},
#   {'id': 30, 'binary': 'Sutter County', 'value': 0.3167091891608791},
#   {'id': 31, 'binary': 'Marin County', 'value': 0.3189327827743098},
#   {'id': 32, 'binary': 'Glenn County', 'value': 0.3065524479126426},
#   {'id': 33, 'binary': 'Shasta County', 'value': 0.32277307281805506},
#   {'id': 35, 'binary': 'Butte County', 'value': 0.3433009012478689},
#   {'id': 37, 'binary': 'Mendocino County', 'value': 0.3046564828562796},
#   {'id': 38, 'binary': 'Lake County', 'value': 0.318682574082189},
#   {'id': 40, 'binary': 'Colusa County', 'value': 0.30343847284906594},
#   {'id': 42, 'binary': 'Siskiyou County', 'value': 0.32258183888564945},
#   {'id': 43, 'binary': 'Lassen County', 'value': 0.30554873919767195},
#   {'id': 46, 'binary': 'Trinity County', 'value': 0.3396080233931315},
#   {'id': 47, 'binary': 'Humboldt County', 'value': 0.30344467175937834},
#   {'id': 48, 'binary': 'Plumas County', 'value': 0.31258574175672127},
#   {'id': 49, 'binary': 'Del Norte County', 'value': 0.32573811363423805},
#   {'id': 53, 'binary': 'Orange County', 'value': None},
#   {'id': 54, 'binary': 'Riverside County', 'value': None},
#   {'id': 55, 'binary': 'San Diego County', 'value': None}],
#  'links': [{'source': 18, 'target': 22},
#   {'source': 21, 'target': 23},
#   {'source': 18, 'target': 23},
#   {'source': 24, 'target': 16},
#   {'source': 25, 'target': 16},
#   {'source': 25, 'target': 24},
#   {'source': 26, 'target': 19},
#   {'source': 26, 'target': 11},
#   {'source': 24, 'target': 25},
#   {'source': 18, 'target': 21},
#   {'source': 21, 'target': 18},
#   {'source': 29, 'target': 22},
#   {'source': 25, 'target': 17},
#   {'source': 30, 'target': 29},
#   {'source': 30, 'target': 3},
#   {'source': 30, 'target': 22},
#   {'source': 18, 'target': 3},
#   {'source': 30, 'target': 24},
#   {'source': 24, 'target': 30},
#   {'source': 26, 'target': 21},
#   {'source': 26, 'target': 3},
#   {'source': 29, 'target': 30},
#   {'source': 30, 'target': 32},
#   {'source': 25, 'target': 3},
#   {'source': 21, 'target': 22},
#   {'source': 21, 'target': 26},
#   {'source': 26, 'target': 23},
#   {'source': 24, 'target': 3},
#   {'source': 18, 'target': 30},
#   {'source': 21, 'target': 3},
#   {'source': 30, 'target': 16},
#   {'source': 24, 'target': 4},
#   {'source': 26, 'target': 13},
#   {'source': 30, 'target': 0},
#   {'source': 18, 'target': 27},
#   {'source': 25, 'target': 13},
#   {'source': 25, 'target': 4},
#   {'source': 30, 'target': 23},
#   {'source': 24, 'target': 0},
#   {'source': 24, 'target': 22},
#   {'source': 30, 'target': 6},
#   {'source': 30, 'target': 4},
#   {'source': 29, 'target': 3},
#   {'source': 30, 'target': 34},
#   {'source': 21, 'target': 27},
#   {'source': 26, 'target': 15},
#   {'source': 18, 'target': 11},
#   {'source': 18, 'target': 19},
#   {'source': 25, 'target': 2},
#   {'source': 30, 'target': 2},
#   {'source': 25, 'target': 11},
#   {'source': 25, 'target': 26},
#   {'source': 30, 'target': 18},
#   {'source': 25, 'target': 6},
#   {'source': 21, 'target': 19},
#   {'source': 24, 'target': 2},
#   {'source': 25, 'target': 20},
#   {'source': 30, 'target': 35},
#   {'source': 24, 'target': 11},
#   {'source': 24, 'target': 35},
#   {'source': 24, 'target': 23},
#   {'source': 21, 'target': 11},
#   {'source': 18, 'target': 26},
#   {'source': 24, 'target': 5},
#   {'source': 24, 'target': 20},
#   {'source': 24, 'target': 7},
#   {'source': 18, 'target': 6},
#   {'source': 25, 'target': 5},
#   {'source': 25, 'target': 30},
#   {'source': 18, 'target': 24},
#   {'source': 24, 'target': 34},
#   {'source': 24, 'target': 6},
#   {'source': 24, 'target': 13},
#   {'source': 25, 'target': 23},
#   {'source': 18, 'target': 28},
#   {'source': 25, 'target': 22},
#   {'source': 18, 'target': 29},
#   {'source': 18, 'target': 9},
#   {'source': 26, 'target': 6},
#   {'source': 18, 'target': 5},
#   {'source': 24, 'target': 17},
#   {'source': 18, 'target': 13},
#   {'source': 24, 'target': 19},
#   {'source': 18, 'target': 4},
#   {'source': 24, 'target': 26},
#   {'source': 18, 'target': 31},
#   {'source': 25, 'target': 10},
#   {'source': 25, 'target': 19},
#   {'source': 21, 'target': 6},
#   {'source': 25, 'target': 7},
#   {'source': 18, 'target': 32},
#   {'source': 26, 'target': 18},
#   {'source': 25, 'target': 33},
#   {'source': 26, 'target': 24},
#   {'source': 25, 'target': 0},
#   {'source': 26, 'target': 25},
#   {'source': 21, 'target': 24},
#   {'source': 18, 'target': 0},
#   {'source': 18, 'target': 2},
#   {'source': 29, 'target': 18},
#   {'source': 26, 'target': 16},
#   {'source': 26, 'target': 17},
#   {'source': 21, 'target': 15},
#   {'source': 29, 'target': 23},
#   {'source': 26, 'target': 9},
#   {'source': 21, 'target': 0},
#   {'source': 26, 'target': 22},
#   {'source': 26, 'target': 4},
#   {'source': 29, 'target': 14},
#   {'source': 21, 'target': 16},
#   {'source': 21, 'target': 9},
#   {'source': 21, 'target': 4},
#   {'source': 21, 'target': 13},
#   {'source': 21, 'target': 31},
#   {'source': 21, 'target': 12},
#   {'source': 21, 'target': 30},
#   {'source': 26, 'target': 2},
#   {'source': 29, 'target': 1},
#   {'source': 26, 'target': 5},
#   {'source': 29, 'target': 0},
#   {'source': 29, 'target': 27},
#   {'source': 21, 'target': 2},
#   {'source': 29, 'target': 8},
#   {'source': 29, 'target': 32},
#   {'source': 29, 'target': 12},
#   {'source': 26, 'target': 31},
#   {'source': 29, 'target': 9},
#   {'source': 29, 'target': 13},
#   {'source': 29, 'target': 2},
#   {'source': 29, 'target': 26},
#   {'source': 29, 'target': 11},
#   {'source': 29, 'target': 7}],
#  'multigraph': False,
#  'graph': []}

# %%
json_data = json.dumps(sampled_network_data, indent=4, ensure_ascii=False, separators=(",", ": "), cls=NpEncoder)

with open('data/network_data_sampled.json', 'w') as f:
    f.write(json_data)
